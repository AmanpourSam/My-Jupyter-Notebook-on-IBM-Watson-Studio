# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## NAME: SAMAN AMANPOUR,
# ## Occupation: Technical Developer

# %% [markdown]
#  ### *I am interested in data science because I am working with big amount of data that must be analyzed.*

# %% [markdown]
# ### This is  a plot of the sinc function:

# %%
# %matplotlib inLine

import numpy as np
import matplotlib.pyplot as plt
pi = np.pi
x= np.linspace (-4*pi, 4*pi,1000)

plt.plot (x, np.sin(x)/x)
plt.show()

# %% [markdown]
# ***
#
# # `Here is some important text!`
#
# ***

# %% [markdown]
# | $$ Name $$ | $$ Descreption $$ |
# | ---- | ----------- |
# | function: | $$
# f(x) = \frac{\sin(x)}{x}
# $$ |
# | Table 1: | mathematical descreption of function |

# %% [markdown]
# The description about sinc function can be found here: <a href="https://en.wikipedia.org/wiki/Sinc_function" target="_blank">this link</a>.
